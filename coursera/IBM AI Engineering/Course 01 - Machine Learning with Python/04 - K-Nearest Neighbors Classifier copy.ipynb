# %% [markdown]
# # K-Nearest Neighbors Classifier

# %% [markdown]
# ## Setup

# %%
# %pip install numpy==2.2.0
# %pip install pandas==2.2.3
# %pip install scikit-learn==1.6.0
# %pip install matplotlib==3.9.3
# %pip install seaborn==0.13.2
# Out:
# Requirement already satisfied: numpy==2.2.0 in c:\python311\lib\site-packages (2.2.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (c:\Python311\Lib\site-packages)
# DEPRECATION: Loading egg at c:\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Ignoring invalid distribution ~ (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (c:\Python311\Lib\site-packages)
# Requirement already satisfied: pandas==2.2.3 in c:\python311\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\python311\lib\site-packages (from pandas==2.2.3) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\andrew-john\appdata\roaming\python\python311\site-packages (from pandas==2.2.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\python311\lib\site-packages (from pandas==2.2.3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\python311\lib\site-packages (from pandas==2.2.3) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\andrew-john\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas==2.2.3) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (c:\Python311\Lib\site-packages)
# DEPRECATION: Loading egg at c:\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Ignoring invalid distribution ~ (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (c:\Python311\Lib\site-packages)
# Requirement already satisfied: scikit-learn==1.6.0 in c:\python311\lib\site-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\python311\lib\site-packages (from scikit-learn==1.6.0) (2.2.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\python311\lib\site-packages (from scikit-learn==1.6.0) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\python311\lib\site-packages (from scikit-learn==1.6.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\python311\lib\site-packages (from scikit-learn==1.6.0) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (c:\Python311\Lib\site-packages)
# DEPRECATION: Loading egg at c:\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Ignoring invalid distribution ~ (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (c:\Python311\Lib\site-packages)
# Requirement already satisfied: matplotlib==3.9.3 in c:\python311\lib\site-packages (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\andrew-john\appdata\roaming\python\python311\site-packages (from matplotlib==3.9.3) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\andrew-john\appdata\roaming\python\python311\site-packages (from matplotlib==3.9.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python311\lib\site-packages (from matplotlib==3.9.3) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python311\lib\site-packages (from matplotlib==3.9.3) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\python311\lib\site-packages (from matplotlib==3.9.3) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\andrew-john\appdata\roaming\python\python311\site-packages (from matplotlib==3.9.3) (24.2)
# Requirement already satisfied: pillow>=8 in c:\python311\lib\site-packages (from matplotlib==3.9.3) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python311\lib\site-packages (from matplotlib==3.9.3) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\andrew-john\appdata\roaming\python\python311\site-packages (from matplotlib==3.9.3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\andrew-john\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib==3.9.3) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (c:\Python311\Lib\site-packages)
# DEPRECATION: Loading egg at c:\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Ignoring invalid distribution ~ (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (c:\Python311\Lib\site-packages)
# Requirement already satisfied: seaborn==0.13.2 in c:\users\andrew-john\appdata\roaming\python\python311\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\python311\lib\site-packages (from seaborn==0.13.2) (2.2.0)
# Requirement already satisfied: pandas>=1.2 in c:\python311\lib\site-packages (from seaborn==0.13.2) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\python311\lib\site-packages (from seaborn==0.13.2) (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\andrew-john\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\andrew-john\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\andrew-john\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (24.2)
# Requirement already satisfied: pillow>=8 in c:\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\andrew-john\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\python311\lib\site-packages (from pandas>=1.2->seaborn==0.13.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\python311\lib\site-packages (from pandas>=1.2->seaborn==0.13.2) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\andrew-john\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (c:\Python311\Lib\site-packages)
# DEPRECATION: Loading egg at c:\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Ignoring invalid distribution ~ (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~p (c:\Python311\Lib\site-packages)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
# %matplotlib inline

# %% [markdown]
# ## Accessing the dataset

# %%
# df = pd.read_csv('../_program resources/teleCust1000t.csv')

df = pd.read_csv("C:/Users/Andrew-John/Documents/_Github/lessons/personal/_resources/APTSHBA.csv")
df
# Out:
#      #                                            Content  \
# 0    6  9915 E Franklin Ave9915 E Franklin Ave, Glenn ...
# 1    3  5122 Decatur St5122 Decatur St, Hyattsville, M...
# 2   19  1961 Lewis Ave1961 Lewis Ave, Rockville, MD 20851
# 3   37                 403 Calvin Ln, Rockville, MD 20851
# 4   16  7726 Acrocomia Dr7726 Acrocomia Dr, Severn, MD...
# 5   25  2863 Chain Bridge Rd2863 Chain Bridge Rd, Vien...
# 6    9  2235 Quincy St NE2235 Quincy St NE, Washington...
# 7   10  3504 18th St NE3504 18th St NE, Washington, DC...
# 8   44          2609 Franklin St NE, Washington, DC 20018
# 9   18    5220 57th Ave5220 57th Ave, Riverdale, MD 20737
# 10  20  7403 Morrison Dr7403 Morrison Dr, Greenbelt, M...
# 11  30  4910 Edgewood Rd4910 Edgewood Rd, College Park...
# 12  42           5006 Cheyenne Pl, College Park, MD 20740
# 13  35         9212 St Andrews Pl, College Park, MD 20740
# 14  28  7514 Creighton Dr7514 Creighton Dr, College Pa...
# 15   1  4804 Aspen Hill Rd4804 Aspen Hill Rd, Rockvill...
# 16  38            1800 Susquehannock Dr, McLean, VA 22101
# 17   2  9911 Stoughton Rd9911 Stoughton Rd, Fairfax, V...
# 18  40               9911 Stoughton Rd, Fairfax, VA 22032
# 19   8  8641 Sumter Ct8641 Sumter Ct, Manassas Park, V...
# 20   4  4803 Russell Ave4803 Russell Ave, Hyattsville,...
# 21  46          1207 Cedarcliff Dr, Glen Burnie, MD 21060
# 22  47            4011 Veazey St NW, Washington, DC 20016
# 23  12  1719 Tulip Ave1719 Tulip Ave, District Heights...
# 24   7  6602 Foster St6602 Foster St, District Heights...
# 25  39              6106 Hellen Lee Dr, Clinton, MD 20735
# 26  26  4018 Alton St4018 Alton St, Capitol Heights, M...
# 27  36          6104 Stonepath Cir, Centreville, VA 20120
# 28  24  5471 Braddock Ridge Dr5471 Braddock Ridge Dr, ...
# 29  23  15012 Olddale Rd15012 Olddale Rd, Centreville,...
# 30  13  215 Oakwood St SE215 Oakwood St SE, Washington...
# 31  14  3907 Martin Luther King Jr Ave SW3907 Martin L...
# 32  43              756 Upsal St SE, Washington, DC 20032
# 33  45               1900 6th St NW, Washington, DC 20001
# 34  48     1805 Marion Barry Ave SE, Washington, DC 20020
# 35  29  1503 Collingwood Ln1503 Collingwood Ln, Silver...
# 36  17  12500 Surrey Cir Dr12500 Surrey Cir Dr, Fort W...
# 37  41            3109 Naylor Rd SE, Washington, DC 20020
# 38  21  5201 Banks Pl NE5201 Banks Pl NE, Washington, ...
# 39  11  302 19th St NE302 19th St NE, Washington, DC 2...
# 40  32     5027 H St SE5027 H St SE, Washington, DC 20019
# 41  22  1815 Vernon St NW1815 Vernon St NW, Washington...
# 42  34  7406 Austin St7406 Austin St, Annandale, VA 22003
# 43  27  22 Solitaire Ct22 Solitaire Ct, Gaithersburg, ...
# 44   5           20825 Apollo Terrace20825 Apollo Terrace
# 45  15  3608 Isbell St3608 Isbell St, Silver Spring, M...
#
#                                      Google Maps Link  \
# 0   https://www.google.com/maps/place/9915+E+Frank...
# 1   https://www.google.com/maps/place/5122+Decatur...
# 2   https://www.google.com/maps/place/1961+Lewis+A...
# 3   https://www.google.com/maps/place/403+Calvin+L...
# 4   https://www.google.com/maps/place/7726+Acrocom...
# 5   https://www.google.com/maps/place/2863+Chain+B...
# 6   https://www.google.com/maps/place/2235+Quincy+...
# 7   https://www.google.com/maps/place/3504+18th+St...
# 8   https://www.google.com/maps/place/2609+Frankli...
# 9   https://www.google.com/maps/place/5220+57th+Av...
# 10  https://www.google.com/maps/place/7403+Morriso...
# 11  https://www.google.com/maps/place/4910+Edgewoo...
# 12  https://www.google.com/maps/place/5006+Cheyenn...
# 13  https://www.google.com/maps/place/9212+St+Andr...
# 14  https://www.google.com/maps/place/7514+Creight...
# 15  https://www.google.com/maps/place/4804+Aspen+H...
# 16  https://www.google.com/maps/place/1800+Susqueh...
# 17  https://www.google.com/maps/place/9911+Stought...
# 18  https://www.google.com/maps/place/9911+Stought...
# 19  https://www.google.com/maps/place/8641+Sumter+...
# 20  https://www.google.com/maps/place/4803+Russell...
# 21  https://www.google.com/maps/place/1207+Cedarcl...
# 4                 7726 Acrocomia Dr, Severn, MD 21076  ...
# 5              2863 Chain Bridge Rd, Vienna, VA 22181  ...
# 6             2235 Quincy St NE, Washington, DC 20018  ...
# 7               3504 18th St NE, Washington, DC 20018  ...
# 8           2609 Franklin St NE, Washington, DC 20018  ...
# 9                  5220 57th Ave, Riverdale, MD 20737  ...
# 10              7403 Morrison Dr, Greenbelt, MD 20770  ...
# 11           4910 Edgewood Rd, College Park, MD 20740  ...
# 12           5006 Cheyenne Pl, College Park, MD 20740  ...
# 13         9212 St Andrews Pl, College Park, MD 20740  ...
# 14          7514 Creighton Dr, College Park, MD 20740  ...
# 15            4804 Aspen Hill Rd, Rockville, MD 20853  ...
# 16            1800 Susquehannock Dr, McLean, VA 22101  ...
# 17               9911 Stoughton Rd, Fairfax, VA 22032  ...
# 18               9911 Stoughton Rd, Fairfax, VA 22032  ...
# 19            8641 Sumter Ct, Manassas Park, VA 20111  ...
# 20            4803 Russell Ave, Hyattsville, MD 20782  ...
# 21          1207 Cedarcliff Dr, Glen Burnie, MD 21060  ...
# 22            4011 Veazey St NW, Washington, DC 20016  ...
# 23         1719 Tulip Ave, District Heights, MD 20747  ...
# 24         6602 Foster St, District Heights, MD 20747  ...
# 25              6106 Hellen Lee Dr, Clinton, MD 20735  ...
# 26           4018 Alton St, Capitol Heights, MD 20743  ...
# 27          6104 Stonepath Cir, Centreville, VA 20120  ...
# 28      5471 Braddock Ridge Dr, Centreville, VA 20120  ...
# 29            15012 Olddale Rd, Centreville, VA 20120  ...
# 30            215 Oakwood St SE, Washington, DC 20032  ...
# 31  3907 Martin Luther King Jr Ave SW, Washington,...  ...
# 32              756 Upsal St SE, Washington, DC 20032  ...
# 33               1900 6th St NW, Washington, DC 20001  ...
# 34     1805 Marion Barry Ave SE, Washington, DC 20020  ...
# 35       1503 Collingwood Ln, Silver Spring, MD 20904  ...
# 36     12500 Surrey Cir Dr, Fort Washington, MD 20744  ...
# 37            3109 Naylor Rd SE, Washington, DC 20020  ...
# 38             5201 Banks Pl NE, Washington, DC 20019  ...
# 39               302 19th St NE, Washington, DC 20002  ...
# 40                 5027 H St SE, Washington, DC 20019  ...
# 41            1815 Vernon St NW, Washington, DC 20009  ...
# 42                7406 Austin St, Annandale, VA 22003  ...
# 43            22 Solitaire Ct, Gaithersburg, MD 20878  ...
# 44            20825 Apollo Terrace, Ashburn, VA 20147  ...
# 45            3608 Isbell St, Silver Spring, MD 20906  ...
#
#       Higher or lower than average  Above/Below Average Population Households  \
# 0    Lower than Average Population                           -0.81       2175
# 1    Lower than Average Population                           -0.70       3853
# 2    Lower than Average Population                           -0.60       4891
# 3    Lower than Average Population                           -0.60       4891
# 4    Lower than Average Population                           -0.57       6348
# 5    Lower than Average Population                           -0.58       5233
# 6    Lower than Average Population                           -0.46       7861
# 7    Lower than Average Population                           -0.46       7861
# 8    Lower than Average Population                           -0.46       7861
# 9    Lower than Average Population                           -0.41       5798
# 10   Lower than Average Population                           -0.31      10198
# 11   Lower than Average Population                           -0.16       9481
# 12   Lower than Average Population                           -0.16       9481
# 13   Lower than Average Population                           -0.16       9481
# 14   Lower than Average Population                           -0.16       9481
# 15   Lower than Average Population                           -0.19       9860
# 16   Lower than Average Population                           -0.19      10643
# 17   Lower than Average Population                           -0.19       9713
# 18   Lower than Average Population                           -0.19       9713
# 19   Lower than Average Population                           -0.08       9782
# 20   Lower than Average Population                           -0.07      11434
# 21   Lower than Average Population                           -0.14      12506
# 22   Lower than Average Population                           -0.06      14069
# 23  Higher than Average Population                            0.01      14634
# 24  Higher than Average Population                            0.01      14634
# 25  Higher than Average Population                            0.03      12473
# 26  Higher than Average Population                            0.05      14122
# 27  Higher than Average Population                            0.09      13752
# 28  Higher than Average Population                            0.09      13752
# 29  Higher than Average Population                            0.09      13752
# 30  Higher than Average Population                            0.10      14511
# 31  Higher than Average Population                            0.10      14511
# 32  Higher than Average Population                            0.10      14511
# 33  Higher than Average Population                            0.20      18266
# 34  Higher than Average Population                            0.47      21310
# 35  Higher than Average Population                            0.52      20908
# 36  Higher than Average Population                            0.41      18533
# 37  Higher than Average Population                            0.47      21310
# 38  Higher than Average Population                            0.55      23190
# 39  Higher than Average Population                            0.60      25395
# 40  Higher than Average Population                            0.55      23190
# 41  Higher than Average Population                            0.38      26999
# 42  Higher than Average Population                            0.61      19190
# 43  Higher than Average Population                            0.72      22781
# 44  Higher than Average Population                            0.68      21139
# 45  Higher than Average Population                            0.85      25100
#
#    White Hispanic Black  Asian Mixed  Other  Sum
# 0   0.15     0.09  0.64   0.07  0.04   0.01  1.0
# 1   0.24     0.40  0.31   0.02  0.02   0.01  1.0
# 2   0.36     0.36  0.09   0.15  0.04   0.00  1.0
# 3   0.36     0.36  0.09   0.15  0.04   0.00  1.0
# 4   0.47     0.05  0.27   0.15  0.05   0.01  1.0
# 5   0.64     0.10  0.05   0.16  0.04   0.00  1.0
# 6   0.12     0.04  0.81   0.01  0.01   0.00  1.0
# 7   0.12     0.04  0.81   0.01  0.01   0.00  1.0
# 8   0.12     0.04  0.81   0.01  0.01   0.00  1.0
# 9   0.12     0.49  0.33   0.03  0.02   0.01  1.0
# 10  0.22     0.13  0.53   0.09  0.03   0.01  1.0
# 11  0.48     0.15  0.18   0.16  0.03   0.00  1.0
# 12  0.48     0.15  0.18   0.16  0.03   0.00  1.0
# 13  0.48     0.15  0.18   0.16  0.03   0.00  1.0
# 14  0.48     0.15  0.18   0.16  0.03   0.00  1.0
# 15  0.52     0.22  0.12   0.11  0.03   0.01  1.0
# 16  0.73     0.06  0.02   0.16  0.03   0.00  1.0
# 17  0.66     0.09  0.04   0.18  0.03   0.00  1.0
# 18  0.66     0.09  0.04   0.18  0.03   0.00  1.0
# 19  0.44     0.34  0.10   0.09  0.03   0.01  1.0
# 20  0.14     0.40  0.41   0.03  0.02   0.00  1.0
# 21  0.70     0.07  0.17   0.03  0.03   0.01  1.0
# 22  0.73     0.10  0.06   0.06  0.04   0.00  1.0
# 23  0.03     0.05  0.90   0.01  0.02   0.00  1.0
# 24  0.03     0.05  0.90   0.01  0.02   0.00  1.0
# 25  0.07     0.03  0.86   0.02  0.01   0.00  1.0
# 26  0.03     0.05  0.90   0.00  0.02   0.00  1.0
# 27  0.51     0.11  0.06   0.28  0.05   0.00  1.0
# 28  0.51     0.11  0.06   0.28  0.05   0.00  1.0
# 29  0.51     0.11  0.06   0.28  0.05   0.00  1.0
# 30  0.08     0.02  0.88   0.00  0.02   0.01  1.0
# 31  0.08     0.02  0.88   0.00  0.02   0.01  1.0
# 32  0.08     0.02  0.88   0.00  0.02   0.01  1.0
# 33  0.36     0.08  0.47   0.07  0.02   0.00  1.0
# 34  0.02     0.02  0.94   0.01  0.01   0.01  1.0
# 35  0.23     0.13  0.45   0.14  0.04   0.00  1.0
# 36  0.08     0.10  0.72   0.06  0.03   0.00  1.0
# 37  0.02     0.02  0.94   0.01  0.01   0.01  1.0
# 38  0.01     0.03  0.95   0.00  0.01   0.00  1.0
# 39  0.39     0.06  0.50   0.03  0.02   0.01  1.0
# 40  0.01     0.03  0.95   0.00  0.01   0.00  1.0
# 41  0.60     0.12  0.19   0.06  0.03   0.01  1.0
# 42  0.42     0.26  0.08   0.22  0.03   0.00  1.0
# 43  0.50     0.13  0.10   0.24  0.03   0.01  1.0
# 44  0.57     0.12  0.09   0.18  0.04   0.01  1.0
# 45  0.27     0.31  0.26   0.12  0.03   0.01  1.0
#
# [46 rows x 29 columns]

# %%
df['custcat'].value_counts()
# Out:
# custcat
# 3    281
# 1    266
# 4    236
# 2    217
# Name: count, dtype: int64

# %%
correlation_matrix = df.corr()

# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
# plt.show()

# %%
correlation_values = abs(df.corr()['custcat']).drop('custcat').sort_values(ascending=False)
correlation_values

# Observe that education and tenure have the highest correlation with the target variable custcat.
# Observe that retirement and gender have the lowest correlation with the target variable custcat.
# Out:
# ed         0.193864
# tenure     0.166691
# income     0.134525
# employ     0.110011
# marital    0.083836
# reside     0.082022
# address    0.067913
# age        0.056909
# region     0.023771
# retire     0.008908
# gender     0.004966
# Name: custcat, dtype: float64

# %%
#  Split the data into features and target variable
# X is the feature set
# y is the target variable
X = df.drop('custcat', axis=1)
y = df['custcat']

# %% [markdown]
# ## Normalize Data

# %%
X_norm = StandardScaler().fit_transform(X)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)

# %% [markdown]
# ## KNN Classification

# %% [markdown]
# ### Training

# %%
k = 3 # What is the accuracy result? 0.275
# k = 6 # What is the accuracy result? 0.29
# Train model and predict
knn = KNeighborsClassifier(n_neighbors=k)
knn_model = knn.fit(X_train, y_train)

# %% [markdown]
# ### Predicting

# %%
# What is yhat?
# yhat is the predicted labels for the test set
yhat = knn_model.predict(X_test)

# %% [markdown]
# ### Accuracy Evaluation

# %%
print("Test set Accuracy: ", accuracy_score(y_test, yhat))
# Out:
# Test set Accuracy:  0.275

# %% [markdown]
# ### Choosing the correct value of k

# %%
# What is Ks, acc, std_acc?
# Ks is the number of neighbors to consider for KNN
# acc is the accuracy of the model for each value of k
# std_acc is the standard deviation of the accuracy for each value of k
# What does np.zeros do?
# np.zeros creates an array of zeros with the specified shape with the length equaling the value of variable 'Ks'
# This allows us to initialize the arrays for storing accuracy results 

Ks = 10 # Result? The best accuracy was with 0.345 when k = 7
# Ks = 30 # Result? The best accuracy was with 0.36 when k = 28
# Ks = 100 # Result? The best accuracy was with 0.4 when k = 78
# Ks = 800 # Result? The best accuracy was with 0.405 when k = 114
acc = np.zeros((Ks))
std_acc = np.zeros((Ks))

# Loop through different values of k (number of neighbors)
# Using Ks+1 to include the last desired value in the range (1 to Ks, i.e., 1 to 10) - remember Python is 0-indexed
for n_neighbors in range(1, Ks+1):
    # Train model and predict
    knn = KNeighborsClassifier(n_neighbors=n_neighbors).fit(X_train, y_train) # Create a KNN classifier with the current value of k
    yhat = knn.predict(X_test) # Predict the labels for the test set
    acc[n_neighbors-1] = accuracy_score(y_test, yhat) # Store the accuracy score for the current value of k
    std_acc[n_neighbors-1] = np.std(yhat == y_test) / np.sqrt(yhat.shape[0]) # Store the standard deviation of the accuracy score for the current value of k

# %% [markdown]
# ### Plot the model accuracy for the range of numbers of neighbors (1 - Ks)

# %%
plt.plot(range(1,Ks+1),acc,'g') # Plot the accuracy scores for the range of 1-ks neighbors with 'g' indicating green color
plt.fill_between(range(1, Ks+1), acc - 1 * std_acc, acc + 1 * std_acc, alpha=0.10) # Fill the area between the upper and lower bounds of the accuracy scores with a transparency of 0.10
plt.legend(('Accuracy', 'Standard Deviation')) # First value is the label for the accuracy line, second value is the label for the standard deviation area
plt.ylabel('Model Accuracy') # Label for the y-axis
plt.xlabel('Number of Neighbors (k)') # Label for the x-axis
plt.tight_layout() # Adjust the layout of the plot to make it look better
plt.show() # Show the plot

# %%
print(f"For Ks = {Ks}, the best accuracy was with {acc.max()} when k = {acc.argmax()+1}") # Print the maximum accuracy and the corresponding value of k
# Out:
# For Ks = 10, the best accuracy was with 0.345 when k = 7

# %% [markdown]
# ![image.png](attachment:image.png)
#
# For Ks = 10, the best accuracy was with 0.345 when k = 7

# %% [markdown]
# ![image.png](attachment:image.png)
#
# For Ks = 30, the best accuracy was with 0.36 when k = 28

# %% [markdown]
# ![image.png](attachment:image.png)
#
# For Ks = 100, the best accuracy was with 0.4 when k = 78

# %% [markdown]
# ![image.png](attachment:image.png)
#
# For Ks = 800, the best accuracy was with 0.405 when k = 114

# %% [markdown]
# ## Why does model performance deteriorate as k increases in value?

# %% [markdown]
# - The model performance deteriorates with more neighbors because the model becomes too generalized and starts to include noise in the data, leading to overfitting.
# - The model may also become less sensitive to the underlying patterns in the data, resulting in a decrease in accuracy.
